# %%
import time   # This module is used for the loading sequence.
import getpass    # This module is used for encrypting the password.


username = 'puffdaddy'     # The chosen username.
password = 'puffkings123'  #  The chosen password.

username_input = input('Username: ') # Grant access if this password is input.

p = getpass.getpass('Password: ')  # Encrypt the password to not show but use *.

# If access is granted, the following should happen.
if username_input == username and p == password:
  print('Access granted')
  time.sleep(3)
  print('***********')
  time.sleep(1)
  print("Locating data")
  time.sleep(2)
  print("***********")
  time.sleep(1)
  print("Accessing files")
  time.sleep(2)
  print("***********")
  time.sleep(1)
  print("Decrypting data")
  time.sleep(1)
  print("***********")
  time.sleep(1)
  print("File is ready")
  
 # If only 1/2 is correct, this should happen. 
elif username_input == username and p != password:
  print('ACCESS DENIED')
  print('Password incorrect') 
elif username_input != username and p == password:
  print('Username incorrect')
  
# If username nor password is correct, the following should happen.  
else:
  print('ACCESS DENIED')
  print('Initiating shutdown in 5')
  time.sleep(4)
  print('4')
  time.sleep(3)
  print('3')
  time.sleep(2)
  print('2')
  time.sleep(1)
  print('1')
  print('System shutdown!')
# Out:
# Username: puffdaddy
# Password: ··········
# Access granted
# ***********
# Locating data
# ***********
# Accessing files
# ***********
# Decrypting data
# ***********
# File is ready
